# %% [markdown]
# # **PCA**

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_

plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance.cumsum(), marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA - Explained Variance")
plt.grid(True)
plt.show()

# %%
for i, var in enumerate(explained_variance):
    print(f"PC{i+1}: {var:.2f}")
# Out:
# PC1: 0.17
# PC2: 0.08
# PC3: 0.08
# PC4: 0.07
# PC5: 0.07
# PC6: 0.06
# PC7: 0.06
# PC8: 0.06
# PC9: 0.05
# PC10: 0.04
# PC11: 0.04
# PC12: 0.04
# PC13: 0.04
# PC14: 0.04
# PC15: 0.03
# PC16: 0.03
# PC17: 0.02
# PC18: 0.02
# PC19: 0.01
# PC20: 0.01

# %%
explained_variance.cumsum()
# Out:
# array([0.16780623, 0.25257499, 0.32771695, 0.39995964, 0.46589117,
#        0.52675226, 0.58433694, 0.63943968, 0.69003785, 0.73414676,
#        0.77524496, 0.81395501, 0.85234479, 0.88771647, 0.91607785,
#        0.94112115, 0.96167583, 0.9804401 , 0.9946737 , 1.        ])

# %%
n_components = 10
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# %%
pca_columns = [f'PC{i+1}' for i in range(n_components)]
df_pca = pd.DataFrame(X_pca, columns=pca_columns)
df_pca['num'] = y.values
plt.figure(figsize=(8,6))
sns.scatterplot(x='PC1', y='PC2', hue='num', data=df_pca, palette='viridis')
plt.title('PCA Scatter Plot (PC1 vs PC2)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(title='Target')
plt.show()
