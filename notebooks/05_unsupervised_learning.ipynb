# %% [markdown]
# # **Unsupervised**

# %%
# X_final, uses data after feature selection
inertia = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_final)
    inertia.append(kmeans.inertia_)

# plot Elbow Method
plt.figure(figsize=(8,5))
plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for K-Means')
plt.grid(True)
plt.show()

# %%
k = 2
kmeans = KMeans(n_clusters=k, random_state=42)
cluster_labels = kmeans.fit_predict(X_final)

df_clusters = X_final.copy()
df_clusters['Cluster'] = cluster_labels
df_clusters['Actual'] = y.loc[df_clean.index].values # Filter y to match df_clean index

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

linked = linkage(X_final, method='ward')

# plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(linked, labels=y.loc[df_clean.index].values, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %%
comparison = pd.crosstab(df_clusters['Cluster'], df_clusters['Actual'])
print(comparison)
# Out:
# Actual     0   1
# Cluster
# 0         55  65
# 1        103  61
